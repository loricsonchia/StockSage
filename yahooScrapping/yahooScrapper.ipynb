# %%
# import re
# import json
# import csv
# from io import StringIO
# from bs4 import BeautifulSoup 
# import requests
import yfinance as yf

# %% [markdown]
# # Way 1: Easiest Way of Downloading Stock Data

# %%
ticker = 'TSLA'
df = yf.download(ticker, '2000-01-01', '2024-07-14')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ticker = 'AMZN'
df2 = yf.download(ticker, '2000-01-01', '2024-07-14')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ticker = 'AMD'
df3 = yf.download(ticker, '2000-01-01', '2024-07-14')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ticker = 'MSFT'
df4 = yf.download(ticker, '2000-01-01', '2024-07-14')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ticker = 'META'
df5 = yf.download(ticker, '2000-01-01', '2024-07-14')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ticker = 'MSTR'
df6 = yf.download(ticker, '2000-01-01', '2024-07-14')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ticker = 'GME'
df7 = yf.download(ticker, '2019-01-11', '2022-01-29')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ticker = 'TRBO'
df8 = yf.download(ticker, '2018-03-30', '2021-04-09')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ticker = 'APPB'
df9 = yf.download(ticker, '2018-03-25', '2021-04-13')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ticker = 'AEMD'
df10 = yf.download(ticker, '2018-01-22', '2021-02-07')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ticker = 'NBDR'
df11 = yf.download(ticker, '2018-03-11', '2021-04-03')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-07-08  247.710007  259.440002  244.570007  252.940002  252.940002
# 2024-07-09  251.000000  265.609985  250.300003  262.329987  262.329987
# 2024-07-10  262.799988  267.589996  257.859985  263.260010  263.260010
# 2024-07-11  263.299988  271.000000  239.649994  241.029999  241.029999
# 2024-07-12  235.800003  251.839996  233.089996  248.229996  248.229996
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %%
df.to_csv('TSLA.csv')

# %%
df2.to_csv('AMZN.csv')

# %%
df3.to_csv('AMD.csv')

# %%
df4.to_csv('MSFT.csv')

# %%
df5.to_csv('META.csv')

# %%
df6.to_csv('MSTR.csv')

# %%
df7.to_csv('GME.csv')

# %%
df8.to_csv('TRBO.csv')

# %%
df9.to_csv('APPB.csv')

# %%
df10.to_csv('AEMD.csv')

# %%
df11.to_csv('NBDR.csv')

# %%
df7.head()
# Out:
#               Open    High     Low   Close  Adj Close    Volume
# Date
# 2019-01-11  3.9650  4.0125  3.9425  3.9625   3.832470   9679200
# 2019-01-14  3.9600  4.0350  3.8925  3.9100   3.781693  14443600
# 2019-01-15  3.9000  3.9100  3.7975  3.8825   3.755095   8912800
# 2019-01-16  3.8925  3.9725  3.8450  3.9200   3.791364   7970400
# 2019-01-17  3.8725  3.9575  3.8250  3.9425   3.813126   6972000

# %%
df7
# Out:
#                  Open     High        Low      Close  Adj Close    Volume
# Date
# 2019-01-11   3.965000   4.0125   3.942500   3.962500   3.832470   9679200
# 2019-01-14   3.960000   4.0350   3.892500   3.910000   3.781693  14443600
# 2019-01-15   3.900000   3.9100   3.797500   3.882500   3.755095   8912800
# 2019-01-16   3.892500   3.9725   3.845000   3.920000   3.791364   7970400
# 2019-01-17   3.872500   3.9575   3.825000   3.942500   3.813126   6972000
# ...               ...      ...        ...        ...        ...       ...
# 2022-01-24  24.754999  25.7150  21.572500  25.037500  25.037500  25039600
# 2022-01-25  24.230000  26.2425  23.752501  24.947500  24.947500  14297200
# 2022-01-26  25.275000  29.7500  25.077499  25.815001  25.815001  33330000
# 2022-01-27  26.035000  26.7500  23.222500  23.379999  23.379999  14644400
# 2022-01-28  23.850000  24.5000  21.902500  24.477501  24.477501  16430400
#
# [769 rows x 6 columns]

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 769 entries, 2019-01-11 to 2022-01-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       769 non-null    float64
#  1   High       769 non-null    float64
#  2   Low        769 non-null    float64
#  3   Close      769 non-null    float64
#  4   Adj Close  769 non-null    float64
#  5   Volume     769 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 42.1 KB

# %%
df7.info
# Out:
# <bound method DataFrame.info of                  Open     High        Low      Close  Adj Close    Volume
# Date
# 2019-01-11   3.965000   4.0125   3.942500   3.962500   3.832470   9679200
# 2019-01-14   3.960000   4.0350   3.892500   3.910000   3.781693  14443600
# 2019-01-15   3.900000   3.9100   3.797500   3.882500   3.755095   8912800
# 2019-01-16   3.892500   3.9725   3.845000   3.920000   3.791364   7970400
# 2019-01-17   3.872500   3.9575   3.825000   3.942500   3.813126   6972000
# ...               ...      ...        ...        ...        ...       ...
# 2022-01-24  24.754999  25.7150  21.572500  25.037500  25.037500  25039600
# 2022-01-25  24.230000  26.2425  23.752501  24.947500  24.947500  14297200
# 2022-01-26  25.275000  29.7500  25.077499  25.815001  25.815001  33330000
# 2022-01-27  26.035000  26.7500  23.222500  23.379999  23.379999  14644400
# 2022-01-28  23.850000  24.5000  21.902500  24.477501  24.477501  16430400
#
# [769 rows x 6 columns]>

# %%
df7.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  769.000000  769.000000  769.000000  769.000000  769.000000
# mean    15.935861   16.892341   14.967962   15.806622   15.801003
# std     21.078634   22.501372   19.661676   20.809156   20.812576
# min      0.712500    0.735000    0.642500    0.700000    0.700000
# 25%      1.242500    1.300000    1.195000    1.247500    1.247500
# 50%      2.572500    2.622500    2.515000    2.550000    2.550000
# 75%     38.500000   40.000000   36.602501   38.360001   38.360001
# max     94.927498  120.750000   72.877502   86.877502   86.877502
#
#              Volume
# count  7.690000e+02
# mean   3.502336e+07
# std    7.074914e+07
# min    3.272800e+06
# 25%    1.045040e+07
# 50%    1.656560e+07
# 75%    2.954520e+07
# max    7.886316e+08

# %%
df8
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2018-04-02  3.603603  3.903903  3.003003  3.603603   3.603603    2914
# 2018-04-03  3.453453  3.603603  3.003003  3.303303   3.303303    1131
# 2018-04-04  3.153153  3.453453  3.003003  3.303303   3.303303     328
# 2018-04-05  3.003003  3.303303  2.402402  3.003003   3.003003    3238
# 2018-04-06  2.702702  3.003003  2.702702  3.003003   3.003003    1021
# ...              ...       ...       ...       ...        ...     ...
# 2021-04-01  0.003500  0.003500  0.002000  0.002700   0.002700  353515
# 2021-04-05  0.005150  0.005150  0.002700  0.003100   0.003100  368456
# 2021-04-06  0.003100  0.003100  0.001900  0.002000   0.002000  496591
# 2021-04-07  0.003500  0.003500  0.002000  0.002000   0.002000  412071
# 2021-04-08  0.002500  0.003000  0.001900  0.001900   0.001900  660100
#
# [761 rows x 6 columns]

# %%
df9
# Out:
#               Open    High    Low  Close  Adj Close  Volume
# Date
# 2018-03-26  1.9100  2.1000  1.861   2.10       2.10    4144
# 2018-03-27  2.1500  2.1500  2.110   2.11       2.11     537
# 2018-03-28  2.1000  2.1000  1.700   2.00       2.00    3857
# 2018-03-29  2.0000  2.0000  2.000   2.00       2.00     293
# 2018-04-02  2.0000  2.0000  2.000   2.00       2.00     100
# ...            ...     ...    ...    ...        ...     ...
# 2021-04-06  0.0200  0.2100  0.020   0.21       0.21    2250
# 2021-04-07  0.2999  0.2999  0.020   0.02       0.02     610
# 2021-04-08  0.0200  0.0200  0.020   0.02       0.02       0
# 2021-04-09  0.2200  0.4000  0.135   0.25       0.25   38434
# 2021-04-12  0.0500  0.4000  0.050   0.06       0.06    2767
#
# [767 rows x 6 columns]

# %%
df10
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2018-01-22  207.000000  207.000000  195.000000  198.000000  198.000000    1861
# 2018-01-23  210.000000  216.000000  192.000000  205.500000  205.500000    3015
# 2018-01-24  202.500000  204.000000  195.000000  199.500000  199.500000    1557
# 2018-01-25  210.000000  243.000000  202.500000  223.500000  223.500000    5996
# 2018-01-26  222.000000  256.500000  219.000000  243.000000  243.000000    5397
# ...                ...         ...         ...         ...         ...     ...
# 2021-02-01   23.799999   23.799999   21.500000   23.000000   23.000000  104390
# 2021-02-02   23.100000   23.200001   22.100000   22.799999   22.799999   50960
# 2021-02-03   23.299999   23.500000   22.500000   23.000000   23.000000   37570
# 2021-02-04   23.000000   25.400000   23.000000   24.900000   24.900000   45370
# 2021-02-05   25.299999   28.799999   25.299999   27.600000   27.600000  118190
#
# ...

# %%
df11
# Out:
#                Open     High     Low   Close  Adj Close   Volume
# Date
# 2018-03-12  0.00700  0.08000  0.0060  0.0150     0.0150  2698140
# 2018-03-13  0.01500  0.02890  0.0150  0.0200     0.0200  1399485
# 2018-03-14  0.02150  0.02250  0.0100  0.0155     0.0155  1370651
# 2018-03-15  0.01390  0.01650  0.0100  0.0140     0.0140   499381
# 2018-03-16  0.01400  0.02500  0.0130  0.0230     0.0230  1632058
# ...             ...      ...     ...     ...        ...      ...
# 2021-03-26  0.01325  0.01325  0.0095  0.0130     0.0130    32090
# 2021-03-29  0.01500  0.01500  0.0095  0.0095     0.0095    52857
# 2021-03-30  0.01000  0.01400  0.0100  0.0140     0.0140    34267
# 2021-03-31  0.01400  0.01400  0.0110  0.0140     0.0140    51201
# 2021-04-01  0.01300  0.02400  0.0120  0.0150     0.0150   750422
#
# [771 rows x 6 columns]

# %% [markdown]
# # Way 2 Downloading Stock Data

# %%
ticker = 'AAPL'
yfticker = yf.Ticker(ticker)
df_AAPL = yfticker.history(start = '1981-01-01')

# %%
yfinfo = yfticker.info

# %%
yfinfo
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '408 996 1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
df_AAPL
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1981-01-02 00:00:00-05:00    0.118870    0.119731    0.118870    0.118870
# 1981-01-05 00:00:00-05:00    0.116716    0.116716    0.116286    0.116286
# 1981-01-06 00:00:00-05:00    0.111548    0.111548    0.111117    0.111117
# 1981-01-07 00:00:00-05:00    0.106810    0.106810    0.106380    0.106380
# 1981-01-08 00:00:00-05:00    0.104657    0.104657    0.104226    0.104226
# ...                               ...         ...         ...         ...
# 2024-07-08 00:00:00-04:00  227.089996  227.850006  223.250000  227.820007
# 2024-07-09 00:00:00-04:00  227.929993  229.399994  226.369995  228.679993
# 2024-07-10 00:00:00-04:00  229.300003  233.080002  229.250000  232.979996
# 2024-07-11 00:00:00-04:00  231.389999  232.389999  225.770004  227.570007
# 2024-07-12 00:00:00-04:00  228.919998  232.639999  228.679993  230.539993
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
df_AAPL.to_csv("AAPLtwo.csv")

# %%
df.shape
# Out:
# (3533, 6)

# %%
df.info
# Out:
# <bound method DataFrame.info of                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-07-08  247.710007  259.440002  244.570007  252.940002  252.940002
# 2024-07-09  251.000000  265.609985  250.300003  262.329987  262.329987
# 2024-07-10  262.799988  267.589996  257.859985  263.260010  263.260010
# 2024-07-11  263.299988  271.000000  239.649994  241.029999  241.029999
# 2024-07-12  235.800003  251.839996  233.089996  248.229996  248.229996
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# ...
