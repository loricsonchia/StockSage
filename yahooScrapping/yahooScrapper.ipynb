# %%
# import re
# import json
# import csv
# from io import StringIO
# from bs4 import BeautifulSoup 
# import requests
import yfinance as yf

# %% [markdown]
# # Way 1: Easiest Way of Downloading Stock Data

# %%
ticker = 'TSLA'
df = yf.download(ticker, '2000-01-01', '2024-06-28')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ticker = 'AMZN'
df2 = yf.download(ticker, '2000-01-01', '2024-06-28')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ticker = 'AMD'
df3 = yf.download(ticker, '2000-01-01', '2024-06-28')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ticker = 'MSFT'
df4 = yf.download(ticker, '2000-01-01', '2024-06-28')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ticker = 'META'
df5 = yf.download(ticker, '2000-01-01', '2024-06-28')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ticker = 'MSTR'
df6 = yf.download(ticker, '2000-01-01', '2024-06-28')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ticker = 'GME'
df7 = yf.download(ticker, '2000-01-01', '2024-06-28')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-06-21  182.300003  183.949997  180.690002  183.009995  183.009995
# 2024-06-24  184.970001  188.800003  182.550003  182.580002  182.580002
# 2024-06-25  184.399994  187.970001  182.009995  187.350006  187.350006
# 2024-06-26  186.539993  197.759995  186.360001  196.369995  196.369995
# 2024-06-27  195.169998  198.720001  194.050003  197.419998  197.419998
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %%
df.to_csv('TSLA.csv')

# %%
df2.to_csv('AMZN.csv')

# %%
df3.to_csv('AMD.csv')

# %%
df4.to_csv('MSFT.csv')

# %%
df5.to_csv('META.csv')

# %%
df6.to_csv('MSTR.csv')

# %%
df7.to_csv('GME.csv')

# %%
df7.head()
# Out:
#                Open     High      Low    Close  Adj Close    Volume
# Date
# 2002-02-13  2.40625  2.51500  2.38125  2.51250   1.691667  76216000
# 2002-02-14  2.54375  2.54875  2.48125  2.50000   1.683250  11021600
# 2002-02-15  2.50000  2.50625  2.46250  2.48750   1.674834   8389600
# 2002-02-19  2.47500  2.47500  2.34375  2.38750   1.607504   7410400
# 2002-02-20  2.40000  2.46875  2.38125  2.46875   1.662210   6892800

# %%
df7
# Out:
#                 Open       High        Low      Close  Adj Close    Volume
# Date
# 2002-02-13   2.40625   2.515000   2.381250   2.512500   1.691667  76216000
# 2002-02-14   2.54375   2.548750   2.481250   2.500000   1.683250  11021600
# 2002-02-15   2.50000   2.506250   2.462500   2.487500   1.674834   8389600
# 2002-02-19   2.47500   2.475000   2.343750   2.387500   1.607504   7410400
# 2002-02-20   2.40000   2.468750   2.381250   2.468750   1.662210   6892800
# ...              ...        ...        ...        ...        ...       ...
# 2024-06-21  25.24000  25.809999  23.510000  23.930000  23.930000  28004000
# 2024-06-24  23.26000  24.830000  23.240000  23.650000  23.650000  22162900
# 2024-06-25  23.60000  24.969999  22.549999  24.930000  24.930000  27625600
# 2024-06-26  24.60000  25.379999  24.040001  24.200001  24.200001  17903000
# 2024-06-27  24.10000  26.690001  24.059999  25.090000  25.090000  34867000
#
# [5631 rows x 6 columns]

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5631 entries, 2002-02-13 to 2024-06-27
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       5631 non-null   float64
#  1   High       5631 non-null   float64
#  2   Low        5631 non-null   float64
#  3   Close      5631 non-null   float64
#  4   Adj Close  5631 non-null   float64
#  5   Volume     5631 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 307.9 KB

# %%
df7.info
# Out:
# <bound method DataFrame.info of                 Open       High        Low      Close  Adj Close    Volume
# Date
# 2002-02-13   2.40625   2.515000   2.381250   2.512500   1.691667  76216000
# 2002-02-14   2.54375   2.548750   2.481250   2.500000   1.683250  11021600
# 2002-02-15   2.50000   2.506250   2.462500   2.487500   1.674834   8389600
# 2002-02-19   2.47500   2.475000   2.343750   2.387500   1.607504   7410400
# 2002-02-20   2.40000   2.468750   2.381250   2.468750   1.662210   6892800
# ...              ...        ...        ...        ...        ...       ...
# 2024-06-21  25.24000  25.809999  23.510000  23.930000  23.930000  28004000
# 2024-06-24  23.26000  24.830000  23.240000  23.650000  23.650000  22162900
# 2024-06-25  23.60000  24.969999  22.549999  24.930000  24.930000  27625600
# 2024-06-26  24.60000  25.379999  24.040001  24.200001  24.200001  17903000
# 2024-06-27  24.10000  26.690001  24.059999  25.090000  25.090000  34867000
#
# [5631 rows x 6 columns]>

# %%
df7.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  5631.000000  5631.000000  5631.000000  5631.000000  5631.000000
# mean      9.328983     9.644328     9.016939     9.309787     7.972581
# std      10.369933    11.019356     9.727787    10.276129    10.516036
# min       0.712500     0.735000     0.642500     0.700000     0.638794
# 25%       3.657500     3.742500     3.583750     3.662500     2.911412
# 50%       5.967500     6.047500     5.860000     5.960000     4.223275
# 75%      10.500000    10.703750    10.332500    10.508750     7.603707
# max      94.927498   120.750000    72.877502    86.877502    86.877502
#
#              Volume
# count  5.631000e+03
# mean   1.452402e+07
# std    2.985576e+07
# min    2.600000e+05
# 25%    5.389200e+06
# 50%    9.614400e+06
# 75%    1.516300e+07
# max    7.886316e+08

# %% [markdown]
# # Way 2 Downloading Stock Data

# %%
ticker = 'AAPL'
yfticker = yf.Ticker(ticker)
df_AAPL = yfticker.history(start = '1981-01-01')

# %%
yfinfo = yfticker.info

# %%
yfinfo
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '408 996 1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
df_AAPL
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1981-01-02 00:00:00-05:00    0.118870    0.119731    0.118870    0.118870
# 1981-01-05 00:00:00-05:00    0.116716    0.116716    0.116286    0.116286
# 1981-01-06 00:00:00-05:00    0.111548    0.111548    0.111117    0.111117
# 1981-01-07 00:00:00-05:00    0.106810    0.106810    0.106380    0.106380
# 1981-01-08 00:00:00-05:00    0.104657    0.104657    0.104226    0.104226
# ...                               ...         ...         ...         ...
# 2024-06-17 00:00:00-04:00  213.369995  218.949997  212.720001  216.669998
# 2024-06-18 00:00:00-04:00  217.589996  218.630005  213.000000  214.289993
# 2024-06-20 00:00:00-04:00  213.929993  214.240005  208.850006  209.679993
# 2024-06-21 00:00:00-04:00  210.389999  211.889999  207.110001  207.490005
# 2024-06-24 00:00:00-04:00  207.720001  212.699997  206.589996  210.925003
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
df_AAPL.to_csv("AAPL.csv")

# %%
df.shape
# Out:
# (3512, 6)

# %%
df.info
# Out:
# <bound method DataFrame.info of                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-06-05  175.350006  176.149994  172.130005  175.000000  175.000000
# 2024-06-06  174.600006  179.729996  172.729996  177.940002  177.940002
# 2024-06-07  176.130005  179.350006  175.580002  177.479996  177.479996
# 2024-06-10  176.059998  178.570007  173.169998  173.789993  173.789993
# 2024-06-11  173.919998  174.750000  167.410004  170.660004  170.660004
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# ...
